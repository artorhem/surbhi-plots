# %%
import matplotlib.pyplot as plt
#import numpy as np
import pandas as pd
import math


names_bw=['time', 'bw', 'op1', 'write_size', 'op2' ]

# %% [markdown]
# ### Uniform Random on HM-LS

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/uniform-random/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
print(df_bw.shape)
print(df_binned.shape)
# Out:
# (29696, 5)
# (495, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (uniform random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, filled disk, uniform-random\nIO Pattern, no cache eviction (bs=1MB)', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/uniform-random/run2/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
print(df_bw.shape)
print(df_binned.shape)
# Out:
# (5120, 5)
# (86, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (uniform random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, filled disk, uniform-random\nIO Pattern, Cache Eviction in progress (bs=1MB)', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-zoned/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (495, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-zoned, random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-zoned/run2/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (86, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-zoned, random\nIO Pattern (bs=1MB) Cache Eviction in Progress', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (683, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA, random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/run2/bw_log_avg_bw.1.log', names=names_bw)
avg_bw = df_bw['bw'].mean()
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (342, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
#df_bw['bw'] = df_bw['bw'].astype(float)
#df_bw['bw'] = df_bw['bw']/1024
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA, random\nIO Pattern (bs=1MB) Cache Eviction in Progress', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/25Util/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (25Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (768, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/25Util/run2/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (25Util), random\nIO Pattern (bs=1MB) cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (86, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/50Util/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (50Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (768, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/50Util/run2/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (50Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (86, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/90Util/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (90Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (768, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/90Util/run2/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (90Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# (86, 6)

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/75Util/run1/bw_log_avg_bw.1.log', names=names_bw)
#process the bw data
nb_rows = 60
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 60).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
avg_bw = df_bw['bw'].mean()
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA (90Util), random\nIO Pattern (bs=1MB) no cache eviction', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/1M/90-10-LBA/75Util/run2/bw_log_avg_bw.1.log', names=names_bw)
#       2 #process the bw data
#       3 nb_rows = 60
#
# ...

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/4K/90-10-LBA/run1/bw_log_avg_bw.1.log', names=names_bw)
avg_bw = df_bw['bw'].mean()
#process the bw data
nb_rows = 600
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 600).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (384, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
#df_bw['bw'] = df_bw['bw'].astype(float)
#df_bw['bw'] = df_bw['bw']/1024
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA, random\nIO Pattern (bs=1MB) Cache Eviction in Progress', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()

# %%
df_bw = pd.read_csv('/home/surbhi/measurements/worst_case/STL/4K/90-10-LBA/run2/bw_log_avg_bw.1.log', names=names_bw)
avg_bw = df_bw['bw'].mean()
#process the bw data
nb_rows = 2400
df_binned = df_bw.groupby(df_bw.index//nb_rows).mean()
# Calculate cumulative GBs of data written
df_binned['cumulative_gb'] = (df_binned['write_size'] * 2400).cumsum() / (1024**3)
#df_binned.drop(df_binned[df_binned['cumulative_gb'] > 28.0].index)
#pd.set_option('display.max_rows', 500)
#print(df_bw.shape)
print(df_binned.shape)
#df_binned
# Out:
# (547, 6)

# %%
#Create the line plots
plt.figure(figsize=(8, 6), dpi=80)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42


fig, ax = plt.subplots()
ax.plot(df_binned['cumulative_gb'], df_binned['bw'], linestyle='-')

# Add labels and title
plt.xlabel('Cumulative GBs Written (random writes to a filled disk)', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Bandwidth (KB/sec)', fontsize=16)
plt.yticks(fontsize=14)
#df_bw['bw'] = df_bw['bw'].astype(float)
#df_bw['bw'] = df_bw['bw']/1024
avg_bw_str = str(round(avg_bw, 2)) + 'KB/sec'
plt.axhline(y=avg_bw, color='r', linestyle='-', label='Avg Bandwidth: ' + avg_bw_str)
plt.title('DM-Hybrid, full disk 90-10-LBA, random\nIO Pattern (bs=1MB) Cache Eviction in Progress', fontsize=16)
labels = plt.gca().get_xticklabels()
label_to_change = labels[-1].set_color('red')
plt.legend(loc='upper left', fontsize=14)

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('/tmp/tmp.pdf', bbox_inches='tight')
plt.show()
