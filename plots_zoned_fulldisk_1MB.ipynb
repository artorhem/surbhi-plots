# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import seaborn as sns

names_bw=['time', 'bw', 'op1', 'size', 'op2' ]
names_latency=['op1', 'latency', 'op2', 'write_size', 'op3']

# %% [markdown]
# ## Zoned, Full disk with bs=1MB
# ### HM-LS : BW and Latency

# %%
# df_bw = pd.read_csv("lsdm/zoned/fullDisk/qd1/bs1MB/bw_log_bw.1.log", sep=",", names=names_bw)

# #process the bw data
# #convert the bw to MB/s
# df_bw1 = df_bw['bw']/1024
# df_bw['bw'] = df_bw1
# #convert the time to seconds
# df_bw['time'] = df_bw['time']/1000

# #plot bw
# plt.plot(df_bw['time'], df_bw['bw'], linestyle='-')
# # Add labels and title
# plt.xlabel('Time (seconds)')
# # plt.xticks(np.arange(0, 45, 5))
# plt.ylabel('Bandwidth (MB/s)')
# # plt.yticks(np.arange(0, 25000, 2500))
# plt.title('Bandwidth of HMLS on 80:20 Zoned IO Pattern (Full Disk, bs=1MB)')

# # Show the plot
# plt.grid(True)  # Optionally, add grid lines
# plt.savefig('fig/final/hmls_zoned_fulldisk_1mb_80_20_bw.png')
# plt.show()

# %%
df_latency = pd.read_csv("lsdm/zoned/fullDisk/qd1/bs1MB/lat_log_lat.1.log", sep=",", names=names_latency)

#process the bw data
df_latency['latency'] = df_latency['latency'] / (1000*1000)  # Convert nanoseconds to microseconds
# Calculate cumulative GBs of data written
df_latency['cumulative_gb'] = df_latency['write_size'].cumsum() / (1024**3)

#Create the line plots
# plt.plot(df1.index, df1['latency'], linestyle='-')
plt.plot(df_latency['cumulative_gb'], df_latency['latency'], linestyle='-')
# Add labels and title
plt.xlabel('Cumulative GBs Written')
# plt.xticks(np.arange(0, 45, 5))
plt.ylabel('Latency (milliseconds)')
# plt.yticks(np.arange(0, 25000, 2500))
plt.title('Latency of HM-LS on 80:20 Zoned IO Pattern (Full Disk, bs=1MB)')

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('fig/final/hmls_zoned_fulldisk_1mb_80_20_latency.png')
plt.show()

# %% [markdown]
# ### HM-Hybrid : BW and Latency

# %%
# df_bw = pd.read_csv("dm-zoned/zoned/fullDisk/qd1/bs1MB/bw_log_bw.1.log", sep=",", names=names_bw)

# #process the bw data
# #convert the bw to MB/s
# df_bw1 = df_bw['bw']/1024
# df_bw['bw'] = df_bw1
# #convert the time to seconds
# df_bw['time'] = df_bw['time']/1000

# #plot bw
# plt.plot(df_bw['time'], df_bw['bw'], linestyle='-')
# # Add labels and title
# plt.xlabel('Time (seconds)')
# # plt.xticks(np.arange(0, 45, 5))
# plt.ylabel('Bandwidth (MB/s)')
# # plt.yticks(np.arange(0, 25000, 2500))
# plt.title('Bandwidth of HM-Hybrid on 80:20 Zoned IO Pattern (Full Disk, bs=1MB)')

# # Show the plot
# plt.grid(True)  # Optionally, add grid lines
# plt.savefig('fig/final/hmhybrid_zoned_fulldisk_1mb_80_20_bw.png')
# plt.show()

# %%
df_latency = pd.read_csv("dm-zoned/zoned/fullDisk/qd1/bs1MB/lat_log_lat.1.log", sep=",", names=names_latency)

#process the bw data
df_latency['latency'] = df_latency['latency'] / (1000*1000)  # Convert nanoseconds to microseconds
# Calculate cumulative GBs of data written
df_latency['cumulative_gb'] = df_latency['write_size'].cumsum() / (1024**3)

#Create the line plots
# plt.plot(df1.index, df1['latency'], linestyle='-')
plt.plot(df_latency['cumulative_gb'], df_latency['latency'], linestyle='-')
# Add labels and title
plt.xlabel('Cumulative GBs Written')
# plt.xticks(np.arange(0, 45, 5))
plt.ylabel('Latency (milliseconds)')
# plt.yticks(np.arange(0, 25000, 2500))
plt.title('Latency of HM-Hybrid on 80:20 Zoned IO Pattern (Full Disk, bs=1MB)')

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('fig/final/hmhybrid_zoned_fulldisk_1mb_80_20_latency.png')
plt.show()

# %% [markdown]
# ### DM-Hybrid : BW and Latency

# %%
df_latency = pd.read_csv("dm-zoned/zoned/fullDisk/qd1/bs1MB/lat_log_lat.1.log", sep=",", names=names_latency)

#process the bw data
df_latency['latency'] = df_latency['latency'] / (1000*1000)  # Convert nanoseconds to microseconds
# Calculate cumulative GBs of data written
df_latency['cumulative_gb'] = df_latency['write_size'].cumsum() / (1024**3)

#Create the line plots
# plt.plot(df1.index, df1['latency'], linestyle='-')
plt.plot(df_latency['cumulative_gb'], df_latency['latency'], linestyle='-')
# Add labels and title
plt.xlabel('Cumulative GBs Written')
# plt.xticks(np.arange(0, 45, 5))
plt.ylabel('Latency (milliseconds)')
# plt.yticks(np.arange(0, 25000, 2500))
plt.title('Latency of HM-Hybrid on 80:20 Zoned IO Pattern (Full Disk, bs=1MB)')

# Show the plot
plt.grid(True)  # Optionally, add grid lines
plt.savefig('fig/final/hmhybrid_zoned_fulldisk_1mb_80_20_latency.png')
plt.show()
